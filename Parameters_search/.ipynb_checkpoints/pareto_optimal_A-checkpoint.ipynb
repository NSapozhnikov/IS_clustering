# %%
#!/usr/bin/env python3
# Find pareto optimal for scoring tables from the grid search
# Author: Nikita Sapozhnikov, nikita.sapozhnikov1@gmail.com
# Date: June 08, 2023
# pareto_optimal_A v0.1
# Please check README.txt
# python3 pareto_optimal_A.py

import numpy as np
import datetime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

main_fp = '/mnt/wd/nsap/Clustering/Parameters_search/'

### read scores file
print('Reading consolidated scores file...')
pd_df = pd.read_excel(main_fp+'best_params_clustering_A.xlsx')
print(pd_df)
# Out:
# Reading consolidated scores file...
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score
# 0        1    dbscan        24  0.10            2   0.000935  3.977939
# 1        1   hdbscan       843  0.10            2   0.085788  3.046771
# 2        1    dbscan         1  0.10            3   0.000746  7.253398
# 3        1   hdbscan       437  0.10            3   0.058785  3.400832
# 4        1    dbscan         0  0.10            4   0.000000  0.000000
# ...    ...       ...       ...   ...          ...        ...       ...
# 14251   22   hdbscan         3  0.95           17   0.003395  6.465992
# 14252   22    dbscan         2  0.95           18   0.003499  8.409228
# 14253   22   hdbscan         3  0.95           18   0.003403  6.494573
# 14254   22    dbscan         0  0.95           19   0.000000  0.000000
# 14255   22   hdbscan         3  0.95           19   0.003482  6.658320
#
# [14256 rows x 7 columns]

# %%
### plot each score for each method
# plot sil_score for DBSCAN
sil_dbscan_df = pd_df.loc[(pd_df['algorithm'] == 'dbscan') & (pd_df['chr'] == 2)]
print(sil_dbscan_df)
sns.scatterplot(
    data=sil_dbscan_df, x="min_samples", y="eps", hue="sil_score", size="clusters",
    sizes=(20, 200)
)
# Out:
#      chr algorithm  clusters   eps  min_samples  sil_score   CH_score
# 0      1    dbscan        24  0.10            2   0.000935   3.977939
# 2      1    dbscan         1  0.10            3   0.000746   7.253398
# 4      1    dbscan         0  0.10            4   0.000000   0.000000
# 6      1    dbscan         0  0.10            5   0.000000   0.000000
# 8      1    dbscan         0  0.10            6   0.000000   0.000000
# ..   ...       ...       ...   ...          ...        ...        ...
# 638    1    dbscan         4  0.95           15   0.000847   7.032266
# 640    1    dbscan         4  0.95           16   0.000857   7.154782
# 642    1    dbscan         2  0.95           17   0.000637   8.988407
# 644    1    dbscan         1  0.95           18   0.000537   9.940236
# 646    1    dbscan         1  0.95           19   0.000541  10.301513
#
# [324 rows x 7 columns]
# <AxesSubplot: xlabel='min_samples', ylabel='eps'>

# %%
# Initialize an empty list to store the Pareto optimal solutions
pareto_optimal = []

# Iterate over each row in the DataFrame
for i, row in sil_dbscan_df.iterrows():
    is_pareto = True
    for j, compare_row in sil_dbscan_df.iterrows():
        # Check if the current row dominates any other row
        if (row['clusters'] < compare_row['clusters'] and row['sil_score'] <= compare_row['sil_score']) or \
                (row['clusters'] <= compare_row['clusters'] and row['sil_score'] < compare_row['sil_score']):
            is_pareto = False
            break
    if is_pareto:
        pareto_optimal.append(row)

# Convert the Pareto optimal solutions list back to a DataFrame
pareto_df = pd.DataFrame(pareto_optimal)

print(pareto_df[['eps', 'min_samples']])
print(pareto_df)
# Out:
#       eps  min_samples
# 1    0.10            2
# 37   0.15            2
# 73   0.20            2
# 109  0.25            2
# 145  0.30            2
# 181  0.35            2
# 217  0.40            2
# 253  0.45            2
# 289  0.50            2
# 325  0.55            2
# 361  0.60            2
# 397  0.65            2
# 433  0.70            2
# 469  0.75            2
# 505  0.80            2
#      chr algorithm  clusters   eps  min_samples  sil_score  CH_score
# 1      1   hdbscan       269  0.10            2   0.018494   3.38781
# 37     1   hdbscan       269  0.15            2   0.018494   3.38781
# 73     1   hdbscan       269  0.20            2   0.018494   3.38781
# 109    1   hdbscan       269  0.25            2   0.018494   3.38781
# 145    1   hdbscan       269  0.30            2   0.018494   3.38781
# 181    1   hdbscan       269  0.35            2   0.018494   3.38781
# 217    1   hdbscan       269  0.40            2   0.018494   3.38781
# 253    1   hdbscan       269  0.45            2   0.018494   3.38781
# 289    1   hdbscan       269  0.50            2   0.018494   3.38781
# 325    1   hdbscan       269  0.55            2   0.018494   3.38781
# 361    1   hdbscan       269  0.60            2   0.018494   3.38781
# 397    1   hdbscan       269  0.65            2   0.018494   3.38781
# 433    1   hdbscan       269  0.70            2   0.018494   3.38781
# 469    1   hdbscan       269  0.75            2   0.018494   3.38781
# 505    1   hdbscan       269  0.80            2   0.018494   3.38781

# %%
def compute_score(row):
    # Extract values from different columns
    clusters = row['clusters']
    sil_score = row['sil_score']
    CH_score = row['CH_score']
    # weighted multiplication
    result = clusters * 0.35 * sil_score * 0.55 * CH_score * 0.1     
    return result

pd_df['computed_score'] = (pd_df['clusters'] * 0.35 * 
                           pd_df['sil_score'] * 0.55 * 
                           pd_df['CH_score'] * 0.1)
best_scores_df = pd.DataFrame(columns=['chr',
                                       'algorithm',
                                       'clusters',
                                       'eps',
                                       'min_samples',
                                       'sil_score',
                                       'CH_score',
                                       'computed_score'])
for num_chr in range(1,23):
    # DBSCAN
    sil_dbscan_df = pd_df.loc[(pd_df['algorithm'] == 'dbscan') & (pd_df['chr'] == num_chr)]
    max_row = sil_dbscan_df[sil_dbscan_df['computed_score'] == sil_dbscan_df['computed_score'].max()]
    print('Best calculated score for DBSCAN: ', max_row, sep='\n')
    # HDBSCAN
    sil_hdbscan_df = pd_df.loc[(pd_df['algorithm'] == 'hdbscan') & (pd_df['chr'] == num_chr)]
    max_row = sil_hdbscan_df[sil_hdbscan_df['computed_score'] == sil_hdbscan_df['computed_score'].max()]
    print('Best calculated score for HDBSCAN: ', max_row, sep='\n')
    print('\n\n')
# Out:
# Best calculated score for DBSCAN:
#      chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 468  1.0    dbscan     966.0  0.75          2.0   0.161984  3.631837
#
#      computed_score
# 468       10.939723
#
# Best calculated score for HDBSCAN:
#      chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 433  1.0   hdbscan     830.0  0.7          2.0    0.08785  3.063074
#
#      computed_score
# 433         4.29942
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 1116  2.0    dbscan    1043.0  0.75          2.0   0.161456  3.804217
#
#       computed_score
# 1116       12.331992
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 1045  2.0   hdbscan     909.0  0.65          2.0   0.087859  3.218005
#
#       computed_score
# 1045        4.947308
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 1764  3.0    dbscan     813.0  0.75          2.0   0.157662  3.691226
#
#       computed_score
# 1764        9.107909
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 1693  3.0   hdbscan     726.0  0.65          2.0   0.091585  3.145172
#
#       computed_score
# 1693        4.025659
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 2448  4.0    dbscan     703.0  0.8          2.0   0.153625  3.382799
#
#       computed_score
# 2448        7.032751
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 2413  4.0   hdbscan     586.0  0.75          2.0   0.087067  2.876371
#
#       computed_score
# 2413        2.825061
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 3060  5.0    dbscan     820.0  0.75          2.0   0.166206  3.871205
#
#       computed_score
# 3060        10.15635
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 3025  5.0   hdbscan     716.0  0.7          2.0   0.093534  3.204272
#
#       computed_score
# 3025        4.130893
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 3708  6.0    dbscan     861.0  0.75          2.0    0.16283  3.850436
#
#       computed_score
# 3708       10.391519
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 3637  6.0   hdbscan     747.0  0.65          2.0   0.087721  3.287596
#
#       computed_score
# 3637        4.146977
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 4356  7.0    dbscan     700.0  0.75          2.0   0.165291    3.6941
#
#       computed_score
# 4356        8.227863
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 4249  7.0   hdbscan     586.0  0.6          2.0   0.094446  3.210456
#
#       computed_score
# 4249        3.420419
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 5004  8.0    dbscan     831.0  0.75          2.0   0.177047  4.420967
#
#       computed_score
# 5004       12.520982
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 4969  8.0   hdbscan     699.0  0.7          2.0   0.110404  3.962364
#
#       computed_score
# 4969        5.886352
#
#
#
# Best calculated score for DBSCAN:
#       chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 5652  9.0    dbscan     624.0  0.75          2.0   0.164099  3.863842
#
#       computed_score
# 5652         7.61625
#
# Best calculated score for HDBSCAN:
#       chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 5473  9.0   hdbscan     530.0  0.5          2.0   0.095386  3.377528
#
#       computed_score
# 5473        3.286933
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 6300  10.0    dbscan     625.0  0.75          2.0   0.160055  3.596473
#
#       computed_score
# 6300        6.925592
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 5833  10.0   hdbscan     567.0  0.10          2.0   0.088165  2.991946
# 5869  10.0   hdbscan     567.0  0.15          2.0   0.088165  2.991946
# 5905  10.0   hdbscan     567.0  0.20          2.0   0.088165  2.991946
# 5941  10.0   hdbscan     567.0  0.25          2.0   0.088165  2.991946
# 5977  10.0   hdbscan     567.0  0.30          2.0   0.088165  2.991946
# 6013  10.0   hdbscan     567.0  0.35          2.0   0.088165  2.991946
# 6049  10.0   hdbscan     567.0  0.40          2.0   0.088165  2.991946
# 6085  10.0   hdbscan     567.0  0.45          2.0   0.088165  2.991946
# 6121  10.0   hdbscan     567.0  0.50          2.0   0.088165  2.991946
# 6157  10.0   hdbscan     567.0  0.55          2.0   0.088165  2.991946
# 6193  10.0   hdbscan     567.0  0.60          2.0   0.088165  2.991946
#
#       computed_score
# 5833        2.879134
# 5869        2.879134
# 5905        2.879134
# 5941        2.879134
# 5977        2.879134
# 6013        2.879134
# 6049        2.879134
# 6085        2.879134
# 6121        2.879134
# 6157        2.879134
# 6193        2.879134
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 6948  11.0    dbscan     602.0  0.75          2.0   0.163936  3.891328
#
#       computed_score
# 6948        7.392639
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 6841  11.0   hdbscan     528.0  0.6          2.0   0.098943  3.403647
#
#       computed_score
# 6841        3.422914
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 7632  12.0    dbscan     593.0  0.8          2.0   0.157003  3.601512
#
#       computed_score
# 7632        6.454745
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 7561  12.0   hdbscan     506.0  0.7          2.0   0.090387  3.125616
#
#       computed_score
# 7561        2.751824
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 8280  13.0    dbscan     452.0  0.8          2.0   0.145786  3.320532
#
#       computed_score
# 8280        4.212051
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 8281  13.0   hdbscan     384.0  0.8          2.0   0.078635  2.798943
#
#       computed_score
# 8281        1.626948
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 8928  14.0    dbscan     420.0  0.8          2.0   0.157063   3.46511
#
#       computed_score
# 8928        4.400185
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 8893  14.0   hdbscan     347.0  0.75          2.0   0.088975  3.006501
#
#       computed_score
# 8893        1.786854
#
#
#
# Best calculated score for DBSCAN:
#        chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 9576  15.0    dbscan     362.0  0.8          2.0   0.155491  3.499933
#
#       computed_score
# 9576        3.792305
#
# Best calculated score for HDBSCAN:
#        chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 9073  15.0   hdbscan     324.0  0.10          2.0   0.085521  2.900075
# 9109  15.0   hdbscan     324.0  0.15          2.0   0.085521  2.900075
# 9145  15.0   hdbscan     324.0  0.20          2.0   0.085521  2.900075
# 9181  15.0   hdbscan     324.0  0.25          2.0   0.085521  2.900075
# 9217  15.0   hdbscan     324.0  0.30          2.0   0.085521  2.900075
# 9253  15.0   hdbscan     324.0  0.35          2.0   0.085521  2.900075
# 9289  15.0   hdbscan     324.0  0.40          2.0   0.085521  2.900075
# 9325  15.0   hdbscan     324.0  0.45          2.0   0.085521  2.900075
# 9361  15.0   hdbscan     324.0  0.50          2.0   0.085521  2.900075
# 9397  15.0   hdbscan     324.0  0.55          2.0   0.085521  2.900075
# 9433  15.0   hdbscan     324.0  0.60          2.0   0.085521  2.900075
# 9469  15.0   hdbscan     324.0  0.65          2.0   0.085521  2.900075
#
#       computed_score
# 9073        1.546891
# 9109        1.546891
# 9145        1.546891
# 9181        1.546891
# 9217        1.546891
# 9253        1.546891
# 9289        1.546891
# 9325        1.546891
# 9361        1.546891
# 9397        1.546891
# 9433        1.546891
# 9469        1.546891
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 10224  16.0    dbscan     396.0  0.8          2.0   0.155164   3.36963
#
#        computed_score
# 10224         3.98564
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 10189  16.0   hdbscan     338.0  0.75          2.0   0.092391  2.901759
#
#        computed_score
# 10189        1.744375
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 10836  17.0    dbscan     364.0  0.75          2.0   0.170034  3.706924
#
#        computed_score
# 10836        4.416526
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 10765  17.0   hdbscan     318.0  0.65          2.0   0.099066  3.043563
# 10801  17.0   hdbscan     318.0  0.70          2.0   0.099066  3.043563
#
#        computed_score
# 10765        1.845707
# 10801        1.845707
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 11520  18.0    dbscan     419.0  0.8          2.0   0.166548  3.574994
#
#        computed_score
# 11520        4.802403
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 11413  18.0   hdbscan     346.0  0.65          2.0   0.091897  3.077835
#
#        computed_score
# 11413        1.883889
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 12168  19.0    dbscan     217.0  0.8          2.0   0.143447  3.212453
#
#        computed_score
# 12168        1.924941
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 12133  19.0   hdbscan     211.0  0.75          2.0   0.073963  2.463052
#
#        computed_score
# 12133        0.739945
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 12780  20.0    dbscan     336.0  0.75          2.0   0.172178  3.672431
#
#        computed_score
# 12780        4.089799
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 12709  20.0   hdbscan     292.0  0.65          2.0   0.088208  2.909029
#
#        computed_score
# 12709        1.442339
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 13464  21.0    dbscan     239.0  0.8          2.0   0.169594  3.607337
#
#        computed_score
# 13464        2.814652
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters  eps  min_samples  sil_score  CH_score  \
# 13321  21.0   hdbscan     203.0  0.6          2.0   0.100371  3.264852
#
#        computed_score
# 13321        1.280557
#
#
#
# Best calculated score for DBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 14076  22.0    dbscan     211.0  0.75          2.0    0.16886  3.770809
#
#        computed_score
# 14076        2.586276
#
# Best calculated score for HDBSCAN:
#         chr algorithm  clusters   eps  min_samples  sil_score  CH_score  \
# 13969  22.0   hdbscan     181.0  0.60          2.0   0.095986  3.219279
# 14005  22.0   hdbscan     181.0  0.65          2.0   0.095986  3.219279
#
#        computed_score
# 13969        1.076653
# 14005        1.076653

# %%
for num_chr in range(1,23):
    sil_hdbscan_df = pd_df.loc[(pd_df['algorithm'] == 'hdbscan') & (pd_df['chr'] == num_chr)]
    max_row = sil_hdbscan_df[sil_hdbscan_df['computed_score'] == sil_hdbscan_df['computed_score'].max()]
    print(max_row)

# %%
# Create a scatter plot using Seaborn
sns.scatterplot(data=sil_dbscan_df, x='clusters', y='sil_score', label='Full Dataset')

# Add a layer for the Pareto optimal solutions
sns.scatterplot(data=pareto_df, x='clusters', y='sil_score', label='Pareto Optimal', marker='x')

# Add labels and title to the plot
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Pareto Optimal Solutions')

# Show the legend
plt.legend()

# Display the plot
plt.show()
